# %%
import datetime
import os
import random
from typing import Any, List, Tuple

import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
import torch
import torch.nn as nn
from fastprogress import master_bar, progress_bar
from nptyping import NDArray
from pandas import DataFrame
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from src.pipelines import market_insight_preprocessing_pipeline as pipeline
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import keras
# Out:
# 2022-03-28 15:23:48.211807: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-28 15:23:48.211852: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# raw_data = pipeline.market_insight_pipeline().run()
raw_data_small = pd.read_csv(
    "../datasets/interim/market_insight_preprocessed.csv",
    parse_dates=["date"],
)
raw_data_small.head()
raw_data_small.groupby("cat_id").count()
# Out:
#         date  product_id  root_cat_id  hits  clicks  popularity  cat_name
# cat_id
# 33        29          29           29    29      29          29        29
# 11037    399         399          399   399     399         399       399
# 11091    228         228          228   228     228         228       228
# 11573    902         902          902   902     902         902       902

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
use_cuda = torch.cuda.is_available()
device
# Out:
# 'cuda'

# %%
# id11573 has mose data with 902 entries
# data_chosen_cat = raw_data.loc[raw_data["cat_id"] == 11573][["hits","clicks", "date"]]
data_chosen_cat_small= raw_data_small.loc[raw_data_small["cat_id"] == 11573][["hits", "date"]]
data_chosen_cat_filled_dates_small = data_chosen_cat_small.groupby(pd.Grouper(key="date", freq="D")).sum()

print(data_chosen_cat_filled_dates_small.head())
dates = data_chosen_cat_filled_dates_small.index.tolist()
print(dates[:2])
data_chosen_cat_filled_dates_small.tail()
# Out:
#             hits
# date
# 2018-12-02     2
# 2018-12-03    16
# 2018-12-04     1
# 2018-12-05     5
# 2018-12-06     3
# [Timestamp('2018-12-02 00:00:00', freq='D'), Timestamp('2018-12-03 00:00:00', freq='D')]
#             hits
# date
# 2021-09-04     3
# 2021-09-05     0
# 2021-09-06     4
# 2021-09-07     0
# 2021-09-08     1

# %%
# DATA BIG
raw_data = pd.read_csv('../datasets/raw/market_insights_overview_all_2022_02_14.csv', parse_dates=["date"])

# Filter away early 2018 data as it seems to contain errors
raw_data =raw_data .loc[raw_data ['date'] > '2018-12-01']

# %%
data_grouped = raw_data.groupby(['cat_id', "date"], as_index=False).count()
data_grouped["date"] = pd.to_datetime(data_grouped["date"])
data_grouped["interest"] = data_grouped["hits"] + data_grouped["clicks"]


data_chosen_categories = data_grouped[["interest", "date", "cat_id",]]
data_chosen_cat = data_grouped.loc[raw_data["cat_id"] == 2][["interest", "date"]]
data_chosen_cat_filled_dates = data_chosen_cat.groupby(pd.Grouper(key="date", freq="D")).sum()
print(data_chosen_cat_filled_dates.head())
# Out:
#             interest
# date
# 2018-12-02      1944
# 2018-12-03      3232
# 2018-12-04      2868
# 2018-12-05      2446
# 2018-12-06      1496

# %%
SEED = 1345


def seed_everything(seed):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True


seed_everything(SEED)

# %%
# Split into train data and validation data
#data = np.array(data_chosen_cat_filled_dates)
data = np.array(data_chosen_cat_filled_dates)
scaler = MinMaxScaler(feature_range=(0.1, 1))
data_normalized = scaler.fit_transform(data)
#test_size = 0.2
#data_validation = data_normalized[-int(test_size * len(data)) :]
#data_train = data_normalized[: -int(test_size * len(data))]
window_input_size = 10
window_output_size = 7
test_size = window_input_size + window_output_size
train_data_normalized = data_normalized[:len(data) -test_size ]
validation_data_normalized= data_normalized[len(data_normalized) - test_size:]
print(train_data_normalized.shape)
print(validation_data_normalized.shape)
# Out:
#   Input In [9]
#     in = data_normalized[: -int(test_size * len(data))]
#     ^
# SyntaxError: invalid syntax

# %%
class TimeseriesDataset(Dataset):
    """
    Custom Dataset subclass.
    Serves as input to DataLoader to transform X
      into sequence data using rolling window.
    DataLoader using this dataset will output batches
      of `(batch_size, seq_len, n_features)` shape.
    Suitable as an input to RNNs.
    """

    def __init__(self, time_series: np.ndarray, seq_len: int, y_size: int):
        self.time_series = torch.tensor(time_series).float()
        self.seq_len = seq_len
        self.y_size = y_size

    def __len__(self):
        return self.time_series.__len__() - (self.seq_len + self.y_size - 1)
        #return self.time_series.__len__() - 1

    def __getitem__(self, index):
        # return x, y
        return (
            self.time_series[index : index + self.seq_len],
            self.time_series[index + self.seq_len : index + self.seq_len + self.y_size],
        )


# Wait, is this a CPU tensor now? Why? Where is .to(device)?

#raw_data = pd.read_csv("../datasets/external/Alcohol_Sales.csv.csv", parse_dates=["DATE"])
train_data = TimeseriesDataset(train_data_normalized, seq_len=window_input_size, y_size=window_output_size)
val_data = TimeseriesDataset(validation_data_normalized, seq_len=window_input_size, y_size=window_output_size)
print(val_data.__len__())
# Out:
# 1

# %%
batch_size = 39
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=False, drop_last=True)
train_loader_no_batch = DataLoader(dataset=train_data, batch_size=1, shuffle=False, drop_last=True)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=False, drop_last=False)
val_loader_no_batch = DataLoader(dataset=val_data, batch_size=1, shuffle=False, drop_last=False)
print("train x shape", next(iter(train_loader))[0].shape)
print("train y shape", next(iter(train_loader))[1].shape)
print("val x shape", next(iter(val_loader))[0].shape)
# Out:
# train x shape torch.Size([39, 10, 1])
# train y shape torch.Size([39, 7, 1])
# val x shape torch.Size([1, 10, 1])

# %%
class LSTMPytorch(nn.Module):
    def __init__(
        self,
        input_size: int,
        hidden_size: int,
        output_size: int,
        num_layers: int,
        learning_rate: float,
        batch_first: bool = True,
        dropout: float = 0.2,
        bidirectional: bool = False,
        optimizer_name: str = "Adam",
        batch_size: int = 1,
    ):
        super(LSTMPytorch, self).__init__()
        self.output_size = output_size  # shape of output
        self.num_layers = num_layers  # number of layers
        self.input_size = input_size  # number of features in each sample
        self.hidden_size = hidden_size  # hidden state
        self.learning_rate = learning_rate  # learning rate
        self.dropout = nn.Dropout(p=dropout)
        self.batch_size = batch_size

        self.criterion = torch.nn.MSELoss()

        self.lstm = nn.LSTM(
            input_size=self.input_size,
            hidden_size=self.hidden_size,
            num_layers=self.num_layers,
            batch_first=True,
        )
        self.fully_conencted_layer = nn.Linear(
            in_features=self.hidden_size, out_features=self.output_size * self.input_size
        )

        parameters = list(self.lstm.parameters()) + list(self.fully_conencted_layer.parameters())
        print(self.lstm.parameters() == parameters)

        if torch.cuda.is_available():
            self.cuda()
            self.criterion.cuda()

        # self.optimizer = torch.optim.Adam(parameters, lr=self.learning_rate,weight_decay=1e-5)
        self.optimizer = getattr(torch.optim, optimizer_name)(self.parameters(), lr=learning_rate)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer, patience=500, factor=0.5, min_lr=1e-7, eps=1e-08
        )
        self.reset_hidden_state(batch_size=batch_size)

    def reset_hidden_state(self, batch_size):
        self.h_0 = Variable(torch.zeros(self.num_layers, batch_size, self.hidden_size, device="cuda:0"))

        self.c_0 = Variable(torch.zeros(self.num_layers, batch_size, self.hidden_size, device="cuda:0"))

    def forward(self, x):
        #self.reset_hidden_state(batch_size=x.size(0), x=x)
        # Here you have defined the hidden state, and internal state first, initialized with zeros.

        # Propagate input through LSTM

        # output (seq_len, batch, hidden_size * num_directions): tensor containing the output features (h_t) from the last layer of the RNN, for each t.
        # h_n (num_layers * num_directions, batch, hidden_size): tensor containing the hidden state for t=seq_len
        # c_n (num_layers * num_directions, batch, hidden_size): tensor containing the cell state for t=seq_len
        ula, (h_out, _) = self.lstm(x, (self.h_0, self.c_0))
        # print("output", ula.shape)
        # Choose the hidden state from the last layer
        last_hidden_state_layer = h_out[-1]
        # h_out = h_out.view(-1, self.hidden_size)
        # out_squashed = ula.view(-1, self.hidden_size)

        out = self.fully_conencted_layer(last_hidden_state_layer)
        # out = self.fc(ula)
        out = self.dropout(out)

        out_multi_feature = out.reshape(out.size(0), self.output_size, self.input_size)
        # return out
        return out_multi_feature

    # Builds function that performs a step in the train loop
    def train_step(self, x, y):
        # Sets model to TRAIN mode
        self.train()
        # Makes predictions
        yhat = self(x)
        # print("yhat", yhat.shape)
        # Computes loss
        loss = self.criterion(y, yhat)

        # Computes gradients
        loss.backward()
        # Updates parameters and zeroes gradients
        self.optimizer.step()
        self.optimizer.zero_grad()
        # Returns the loss
        return loss.item()

    def validation_step(self, x, y):
        val_losses = []
        with torch.no_grad():
            self.eval()

            yhat = self(x)
            val_loss = self.criterion(y, yhat)
            val_losses.append(val_loss.item())

        return val_losses

    def train_network(
        self,
        train_loader,
        val_loader,
        n_epochs=100,
        verbose=True,
        optuna_trial: optuna.Trial = None,
    ):
        self.train()
        losses = []
        val_losses = []
        for epoch in progress_bar(range(n_epochs)):
            for x_batch, y_batch in train_loader:
                # the dataset "lives" in the CPU, so do our mini-batches
                # therefore, we need to send those mini-batches to the
                # device where the model "lives"
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                loss = self.train_step(x_batch, y_batch)
                losses.append(loss)

            for x_val, y_val in val_loader:
                x_val = x_val.to(device)
                y_val = y_val.to(device)

                val_loss = self.validation_step(x_val, y_val)
                val_losses.append(val_loss)

            if optuna_trial:
                accuracy = self.calculate_mean_score(val_losses)
                optuna_trial.report(accuracy, epoch)

                if optuna_trial.should_prune():
                    print("Pruning trial!")
                    raise optuna.exceptions.TrialPruned()

            if epoch % 50 == 0:
                print(f"Epoch: {epoch}, loss: {loss}. Validation losses: {val_loss}")
        return losses, val_losses

    def calculate_mean_score(self, losses: List[torch.Tensor]) -> float:
        return np.mean(losses)

# %%
# Train network
lstm = LSTMPytorch(
    input_size=1,
    hidden_size=50,
    output_size=window_output_size,
    num_layers=2,
    learning_rate=0.001,
    batch_size=batch_size,
)
print(lstm)
losses, val_losses = lstm.train_network(train_loader, val_loader, n_epochs=100, verbose=True)
# Out:
# False
# LSTMPytorch(
#   (dropout): Dropout(p=0.2, inplace=False)
#   (criterion): MSELoss()
#   (lstm): LSTM(1, 50, num_layers=2, batch_first=True)
#   (fully_conencted_layer): Linear(in_features=50, out_features=7, bias=True)
# )
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/100 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb Cell 12' in <module>
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000011vscode-remote?line=1'>2</a> lstm = LSTMPytorch(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000011vscode-remote?line=2'>3</a>     input_size=1,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000011vscode-remote?line=3'>4</a>     hidden_size=50,
#    (...)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000011vscode-remote?line=7'>8</a>     batch_size=batch_size,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000011vscode-remote?line=8'>9</a> )
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000011vscode-remote?line=9'>10</a> print(lstm)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000011vscode-remote?line=10'>11</a> losses, val_losses = lstm.train_network(train_loader, val_loader, n_epochs=100, verbose=True)
#
# /home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb Cell 11' in LSTMPytorch.train_network(self, train_loader, val_loader, n_epochs, verbose, optuna_trial)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=130'>131</a>     x_val = x_val.to(device)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=131'>132</a>     y_val = y_val.to(device)
# --> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=133'>134</a>     val_loss = self.validation_step(x_val, y_val)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=134'>135</a>     val_losses.append(val_loss)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=136'>137</a> if optuna_trial:
#
# /home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb Cell 11' in LSTMPytorch.validation_step(self, x, y)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=98'>99</a> with torch.no_grad():
#     <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=99'>100</a>     self.eval()
# --> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=101'>102</a>     yhat = self(x)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=102'>103</a>     val_loss = self.criterion(y, yhat)
#     <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=103'>104</a>     val_losses.append(val_loss.item())
#
# File ~/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1097'>1098</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1098'>1099</a> # this function, and just call forward.
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1099'>1100</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1100'>1101</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1101'>1102</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1102'>1103</a> # Do not call functions when jit is used
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1103'>1104</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb Cell 11' in LSTMPytorch.forward(self, x)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=54'>55</a> def forward(self, x):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=55'>56</a>     #self.reset_hidden_state(batch_size=x.size(0), x=x)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=56'>57</a>     # Here you have defined the hidden state, and internal state first, initialized with zeros.
#    (...)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=61'>62</a>     # h_n (num_layers * num_directions, batch, hidden_size): tensor containing the hidden state for t=seq_len
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=62'>63</a>     # c_n (num_layers * num_directions, batch, hidden_size): tensor containing the cell state for t=seq_len
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=63'>64</a>     ula, (h_out, _) = self.lstm(x, (self.h_0, self.c_0))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=64'>65</a>     # print("output", ula.shape)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=65'>66</a>     # Choose the hidden state from the last layer
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/archie/code/Masteroppgave/notebooks/lstm_market_insight_exploration.ipynb#ch0000010vscode-remote?line=66'>67</a>     last_hidden_state_layer = h_out[-1]
#
# File ~/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1097'>1098</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1098'>1099</a> # this function, and just call forward.
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1099'>1100</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1100'>1101</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1101'>1102</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1102'>1103</a> # Do not call functions when jit is used
#    <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1103'>1104</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py:689, in LSTM.forward(self, input, hx)
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=683'>684</a> else:
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=684'>685</a>     # Each batch of the hidden state should match the input sequence that
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=685'>686</a>     # the user believes he/she is passing in.
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=686'>687</a>     hx = self.permute_hidden(hx, sorted_indices)
# --> <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=688'>689</a> self.check_forward_args(input, hx, batch_sizes)
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=689'>690</a> if batch_sizes is None:
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=690'>691</a>     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=691'>692</a>                       self.dropout, self.training, self.bidirectional, self.batch_first)
#
# File ~/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py:633, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=626'>627</a> def check_forward_args(self,  # type: ignore[override]
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=627'>628</a>                        input: Tensor,
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=628'>629</a>                        hidden: Tuple[Tensor, Tensor],
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=629'>630</a>                        batch_sizes: Optional[Tensor],
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=630'>631</a>                        ):
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=631'>632</a>     self.check_input(input, batch_sizes)
# --> <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=632'>633</a>     self.check_hidden_size(hidden[0], self.get_expected_hidden_size(input, batch_sizes),
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=633'>634</a>                            'Expected hidden[0] size {}, got {}')
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=634'>635</a>     self.check_hidden_size(hidden[1], self.get_expected_cell_size(input, batch_sizes),
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=635'>636</a>                            'Expected hidden[1] size {}, got {}')
#
# File ~/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py:226, in RNNBase.check_hidden_size(self, hx, expected_hidden_size, msg)
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=222'>223</a> def check_hidden_size(self, hx: Tensor, expected_hidden_size: Tuple[int, int, int],
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=223'>224</a>                       msg: str = 'Expected hidden size {}, got {}') -> None:
#     <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=224'>225</a>     if hx.size() != expected_hidden_size:
# --> <a href='file:///home/archie/code/Masteroppgave/venv-pycharm2/lib/python3.9/site-packages/torch/nn/modules/rnn.py?line=225'>226</a>         raise RuntimeError(msg.format(expected_hidden_size, list(hx.size())))
#
# RuntimeError: Expected hidden[0] size (2, 1, 50), got [2, 39, 50]

# %%
plt.plot(losses)
plt.show()
val_losses_flat = [item for sublist in val_losses for item in sublist]
plt.plot(val_losses_flat)

# %%
(lstm.calculate_mean_score(val_losses))
# Out:
# 0.007761603915831074

# %%
# Predict training
correct_values = []
predictions = []
for x_batch, y_batch in train_loader:
    x_batch = x_batch.to(device)
    y_batch = y_batch.to(device)
    yhat = lstm(x_batch)
    print(yhat.shape)

    predictions.extend(yhat[:, 0, 0].detach().cpu().numpy())
    correct_values.extend(y_batch[:, 0, 0].detach().cpu().numpy())
    # correct_values.append(y_batch.cpu().detach().numpy().flatten())
    # predictions.append(yhat.detach().cpu().numpy().flatten())
predictions = np.array(predictions)
correct_values = np.array(correct_values)
plt.plot(correct_values.flatten())
plt.plot(predictions.flatten() )

plt.show()

# Predict validation
correct_values_val = []
predictions_val = []
for x_batch, y_batch in val_loader:
    x_batch = x_batch.to(device)
    y_batch = y_batch.to(device)
    yhat = lstm(x_batch)

    predictions_val.extend(yhat[::7, :, 0].detach().cpu().numpy())
    correct_values_val.extend(y_batch[::7, :, 0].detach().cpu().numpy())
    # correct_values.append(y_batch.cpu().detach().numpy().flatten())
    # predictions.append(yhat.detach().cpu().numpy().flatten())
predictions_val = np.array(predictions_val)
correct_values_val = np.array(correct_values_val)
print("correct values", correct_values_val.shape)
plt.plot(correct_values_val.flatten())
plt.plot(predictions_val.flatten() )
print("train losses", sum(losses)/len(losses))
print("val losses", sum(val_losses_flat)/len(val_losses_flat))
# Out:
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# torch.Size([1, 7, 1])
# correct values (1, 7)
# train losses 0.01626884182758361
# val losses 0.005377984994556755

# %%
x_train = []
y_train = []
x_val = []
y_val = []
for batch in train_loader:
  x, y = batch
  x_train.extend((x.cpu().detach().numpy()))
  y_train.extend((y.cpu().detach().numpy()))
for batch in val_loader_no_batch:
  x, y = batch
  x_val.extend((x.cpu().detach().numpy()))
  y_val.extend((y.cpu().detach().numpy()))
print(x_train[:1])
print(np.array(x_val[:1]))
print(x_train[0].shape)
print(x_val[0].shape)
# Out:
# [array([[0.20384616],
#        [0.2726496 ],
#        [0.25320512],
#        [0.23066239],
#        [0.17991453],
#        [0.191453  ],
#        [0.20747863],
#        [0.25587606],
#        [0.21923077],
#        [0.16239317]], dtype=float32)]
# [[[0.23418804]
#   [0.21047008]
#   [0.2568376 ]
#   [0.23760684]
#   [0.24754274]
#   [0.21677351]
#   [0.27136752]
#   [0.24380341]
#   [0.12745726]
#   [0.19722222]]]
# (10, 1)
# (10, 1)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_val = np.array(x_val)
y_val = np.array(y_val)
print("x_train", x_train.shape)
print("y_train", y_train.shape)
print("X_val", x_val.shape)
print("y_val", y_val.shape)
# Out:
# x_train (1131, 10, 1)
# y_train (1131, 7, 1)
# X_val (1, 10, 1)
# y_val (1, 7, 1)

# %%
regressor = Sequential()
print((batch_size, x_train[0].shape[0], 1))
regressor.add(LSTM(stateful=True, batch_input_shape=(batch_size, x_train[0].shape[0], 1), units = 50, return_sequences = False,))
#regressor.add(LSTM(stateful=False, units = 50, return_sequences = True, input_shape=(x_train[0].shape[1], 1)))

regressor.add(Dropout(0.20))

regressor.add(Dense(units = window_output_size))
opt = keras.optimizer_v2.adam.Adam(learning_rate=0.001)
regressor.compile(optimizer = opt, loss = 'mean_squared_error',)
print(regressor.summary())
# Out:
# (39, 10, 1)
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (39, 50)                  10400
#
#  dropout_11 (Dropout)        (39, 50)                  0
#
#  dense_11 (Dense)            (39, 7)                   357
#
# =================================================================
# Total params: 10,757
# Trainable params: 10,757
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
regressor.fit(x_train, y_train, epochs = 100, batch_size = batch_size)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 1s 4ms/step - loss: 0.0342
# Epoch 2/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 3/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 4/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 5/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 6/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 7/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 8/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 9/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 10/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 11/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 12/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 13/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 14/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 15/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 16/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 17/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 18/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 19/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 20/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 21/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 22/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 23/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 24/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 25/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 26/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 27/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 28/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 29/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 30/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 31/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 32/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 33/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 34/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 35/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 36/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 37/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 38/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 39/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 40/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 41/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 42/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 43/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 44/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 45/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 46/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 47/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 48/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 49/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 50/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 51/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 52/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 53/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 54/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 55/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 56/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 57/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 58/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 59/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 60/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 61/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 62/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 63/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 64/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 65/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 66/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 67/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 68/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 69/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 70/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 71/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 72/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 73/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 74/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 75/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 76/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 77/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 78/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 79/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 80/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 81/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 82/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 83/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 84/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 85/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 86/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 87/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 88/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 89/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 90/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 91/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 92/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 93/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 94/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 95/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 96/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 97/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 98/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 99/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 100/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0040

# %%
print(regressor.summary())
print("Training loss", regressor.evaluate(x_train, y_train, batch_size=batch_size))
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (39, 50)                  10400
#
#  dropout_11 (Dropout)        (39, 50)                  0
#
#  dense_11 (Dense)            (39, 7)                   357
#
# =================================================================
# Total params: 10,757
# Trainable params: 10,757
# Non-trainable params: 0
# _________________________________________________________________
# None
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0039
# Training loss 0.003942121751606464

# %%
regressor_predictor = Sequential()
print((batch_size, x_train[0].shape[0], 1))
regressor_predictor.add(LSTM(stateful=True, batch_input_shape=(1, x_train[0].shape[0], 1), units = 50, return_sequences = False,))
#regressor_predictor.add(LSTM(stateful=False, units = 50, return_sequences = True, input_shape=(x_train[0].shape[1], 1)))
regressor_predictor.add(Dropout(0.20))
regressor_predictor.add(Dense(units = window_output_size))
opt = keras.optimizer_v2.adam.Adam(learning_rate=0.001)
regressor_predictor.compile(optimizer = opt, loss = 'mean_squared_error',)
trained_weights = regressor.get_weights()
regressor_predictor.set_weights(trained_weights)
# Out:
# (39, 10, 1)

# %%
print(x_val.shape)
print(y_val.shape)
# Out:
# (1, 10, 1)
# (1, 7, 1)
# (1131, 10, 1)
# (1131, 7, 1)

# %%
print("validation loss", regressor_predictor.evaluate(x_val, y_val, batch_size=1))
print(regressor_predictor.loss)
y_pred = regressor_predictor.predict(x_train, batch_size=1)
y_pred_val = regressor_predictor.predict(x_val, batch_size=1)
print("y_pred", y_pred.shape)
plt.plot(y_train[::window_output_size, :, 0].flatten())
plt.plot(y_pred[::window_output_size, :].flatten())
plt.show()
plt.plot(y_val[::window_input_size, :, 0].flatten())
plt.plot(y_pred_val[::window_input_size, :].flatten())
# Out:
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033
# validation loss 0.003281449666246772
# mean_squared_error
# y_pred (1131, 7)
