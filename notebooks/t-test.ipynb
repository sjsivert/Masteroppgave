# %%
from scipy import stats
import math

# %%
lo_uni_lstm_ds1_mase = [
1.144,
0.748,
0.597,
0.659,
0.901,
0.553,
0.637,
0.845,
1.743,
1.049,
1.661,
1.500,
2.124,
1.154,
1.704,
0.725,
1.314,
0.674,
0.568,
2.277,
]
lo_uni_lstm_ds1_smape = [
0.151,
0.244,
0.097,
0.161,
0.225,
0.081,
0.346,
0.178,
0.133,
0.186,
0.178,
0.466,
0.192,
0.204,
0.238,
0.250,
0.393,
0.286,
0.064,
0.088,
# ds 2
1.085,
0.360,
1.031,
0.554,
1.063,
0.878,
1.082,
0.329,
0.695,
0.570,
0.349,
0.648,
0.222,
1.107,
0.553,
0.846,
0.849,
0.253,
0.759,
0.439,
# ds 3
0.242,
0.343,
0.368,
0.311,
0.561,
0.539,
0.469,
0.985,
]
lo_mult_lstm_ds1_mase =[
1.473,
0.541,
0.539,
0.626,
0.867,
0.555,
0.631,
0.917,
1.209,
0.851,
1.990,
0.745,
1.636,
0.813,
1.230,
0.740,
1.251,
0.549,
0.819,
1.449,
]
lo_mult_lstm_ds1_smape = [
0.185,
0.172,
0.088,
0.154,
0.216,
0.081,
0.341,
0.189,
0.092,
0.153,
0.218,
0.273,
0.151,
0.150,
0.179,
0.256,
0.371,
0.239,
0.096,
0.056,
#ds 2
0.708,
0.392,
1.059,
0.806,
0.189,
0.825,
0.816,
0.563,
0.692,
0.299,
0.247,
0.471,
0.223,
1.596,
0.222,
1.034,
0.861,
0.218,
0.422,
0.423,
#ds 3
0.100,
0.570,
0.248,
0.171,
0.522,
0.412,
0.393,
0.538,
]
global_uni_lstm_ds1_smape = [
0.279,
0.216,
0.154,
0.156,
0.215,
0.088,
0.330,
0.153,
0.141,
0.219,
0.150,
0.286,
0.189,
0.174,
0.146,
0.227,
0.416,
0.295,
0.163,
0.058,
# ds2
0.819,
0.306,
1.111,
0.653,
0.751,
0.901,
0.969,
0.922,
0.665,
0.500,
0.298,
0.625,
0.294,
1.121,
0.656,
0.812,
0.587,
0.413,
0.376,
0.452,
# ds 3
0.227,
0.261,
0.558,
0.381,
0.366,
0.306,
0.544,
0.760,
]

# %%
#print("lo- mult vs uni- lsttmm\n mase", stats.ttest_rel(lo_uni_lstm_ds1_mase, lo_mult_lstm_ds1_mase))
print("lo vs global \n smape", stats.ttest_rel(lo_uni_lstm_ds1_smape, global_uni_lstm_ds1_smape))
print(sum(lo_uni_lstm_ds1_smape) / len(lo_uni_lstm_ds1_smape))
print(sum(global_uni_lstm_ds1_smape) / len(global_uni_lstm_ds1_smape))
print((0.451 - 0.431) / 0.451 * 100)
# Out:
# lo- mult vs uni- lsttm
#  smape Ttest_relResult(statistic=0.9187195472746553, pvalue=0.36293328984398276)
# 0.4510625000000001
# 0.43102083333333346
# 4.4345898004434625

# %%
print("lo- mult vs uni- lsttm\n smape", stats.ttest_rel(lo_uni_lstm_ds1_smape, lo_mult_lstm_ds1_smape))
print(sum(lo_uni_lstm_ds1_smape) / len(lo_uni_lstm_ds1_smape))
print(sum(lo_mult_lstm_ds1_smape) / len(lo_mult_lstm_ds1_smape))
print((0.451 - 0.389) / 0.451 * 100)
# Out:
# lo- mult vs uni- lsttm
#  smape Ttest_relResult(statistic=2.121544995947556, pvalue=0.03917770592639328)
# 0.4510625000000001
# 0.38916666666666666
# 13.747228381374724
