# %%
import pandas as pd

data = pd.read_csv("../datasets/categories_1000.csv")

# %%
print(data.columns)
print(data.info())
data.head()
# Out:
# Index(['id', 'title', 'alias', 'image_id', 'icon_id', 'url', 'type',
#        'need_parent', 'pointer_id', 'pointer_filter', 'manufacturer_prefix',
#        'filter_query_string', 'filter_cat_id', 'netsprint_buckets', 'modified',
#        'created', 'price_find', 'price_not', 'has_manufacturer_prefix',
#        'redirect_regexp', 'alias_search', 'alias_autocomplete', 'alias_seo',
#        'meta_title', 'meta_description', 'preamble', 'product_view',
#        'product_view_card', 'adult'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1000 non-null   int64
#  1   title                    1000 non-null   object
#  2   alias                    487 non-null    object
#  3   image_id                 983 non-null    float64
# ...

# %%
print(data.describe())
# Out:
#                  id      image_id       icon_id  need_parent    pointer_id  \
# count   1000.000000  9.830000e+02  1.000000e+03          1.0    131.000000
# mean    9504.694000  1.823854e+06  5.413123e+04          1.0   7560.748092
# std     4117.003898  1.006294e+06  4.118296e+05          NaN   5336.829334
# min        1.000000  0.000000e+00  0.000000e+00          1.0      2.000000
# 25%    10322.750000  1.422374e+06  0.000000e+00          1.0    221.000000
# 50%    11303.500000  1.703792e+06  0.000000e+00          1.0  11096.000000
# 75%    11601.250000  2.956760e+06  0.000000e+00          1.0  11427.000000
# max    11876.000000  3.267018e+06  3.191976e+06          1.0  13451.000000
#
#        manufacturer_prefix  filter_cat_id  netsprint_buckets  price_find  \
# count          1000.000000      12.000000        1000.000000         0.0
# mean              0.946000     965.000000           0.995000         NaN
# ...
