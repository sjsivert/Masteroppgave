# %%
import pandas as pd
import matplotlib.pyplot as plt
def load_dataset(data_path):
    return pd.read_csv(data_path)

# %%
data = load_dataset("../datasets/solr_productline_10000.csv")
data.head()
# Out:
#    pricecrawled  metadata         type  test_rating  first_price_date  \
# 0           NaN       NaN  productline          NaN               NaN
# 1           NaN       NaN  productline          NaN               NaN
# 2           NaN       NaN  productline          NaN               NaN
# 3           NaN       NaN  productline          NaN               NaN
# 4           NaN       NaN  productline          NaN               NaN
#
#    campaign_group  price  stock_qty  product_id  price_count  ... price_unit  \
# 0             NaN  179.0          0         NaN          NaN  ...        NaN
# 1             NaN  809.0          0         NaN          NaN  ...        NaN
# 2             NaN  309.0          0         NaN          NaN  ...        NaN
# 3             NaN  359.0          0         NaN          NaN  ...        NaN
# 4             NaN  189.0          0         NaN          NaN  ...        NaN
#
#   price_min_qty product_ids            _version_ offer_ratio  \
# ...

# %%
selected_columns = data[["price", "product_ids", "category", "title", "description"]]

selected_columns.head()
# Out:
#    price  product_ids                                           category  \
# 0  179.0     474433.0             Barneklær > Fleeceklær > Fleecegensere
# 1  809.0     391277.0     Barneklær > Yttertøy > Skallklær > Skallbukser
# 2  309.0          NaN  Barneklær > Yttertøy > Barnejakker > Lettvekts...
# 3  359.0          NaN                        Leker > Treleker > Draleker
# 4  189.0          NaN                    Barneklær > Underdeler > Skjørt
#
#                                           title  \
# 0  Tenson Miracle JR Fleecejakke, Pink, 122-128
# 1       Lindberg Explorer Skallbukse, Green, 90
# 2        Nordbjørn Pine Lettvektjakke, Navy, 98
# 3              Jabadabado Tog Med Klosser Teddy
# 4        Name it Natti Skjørt, Green Gables 134
#
#                                          description
# 0  Miracle JR er en behagelig fleecejakke fra Ten...
# 1  Explorer er en klassisk friluftbukse fra Lindb...
# 2  Pine er en fin lettvektjakke fra Nordbjørn. Ja...
# ...

# %%
selected_columns.describe()
# Out:
#               price    product_ids
# count  10000.000000    3762.000000
# mean     537.511000  430021.861510
# std      946.296571   70678.721284
# min       73.000000  142728.000000
# 25%      189.000000  391393.750000
# 50%      299.000000  446196.000000
# 75%      569.000000  488826.000000
# max    23899.000000  522251.000000

# %%
selected_columns.hist()
plt.show()
