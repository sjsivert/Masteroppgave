# %%
import pandas as pd
import matplotlib.pyplot as plt
def load_dataset(data_path):
    return pd.read_csv(data_path)

# %%
products_raw = load_dataset("../datasets/products_1000.csv")
products_raw.head()
# Out:
#        id              created             modified  manufacturer_id  \
# 0  394561  2019-07-18 09:53:00  2021-09-03 08:10:57            11165
# 1  522362  2021-09-03 08:07:25  2021-09-03 08:10:41              618
# 2  390718  2019-07-02 15:02:13  2021-09-03 08:10:26             5791
# 3  390766  2019-07-03 09:39:15  2021-09-03 08:10:26            14878
# 4  390596  2019-07-01 15:47:02  2021-09-03 08:10:24             6804
#
#              published launch_start launch_end  \
# 0  2019-07-18 09:53:00          NaN        NaN
# 1                  NaN          NaN        NaN
# 2  2019-07-02 15:02:13          NaN        NaN
# 3                  NaN          NaN        NaN
# 4  2019-07-01 15:47:02          NaN        NaN
#
#                                   title title_search_aliases  \
# 0                         Eastpak Floid                  NaN
# 1                         Jabra Elite 3                  NaN
# 2                Didriksons Noor Parkas                  NaN
# ...

# %%
products_raw.describe()
# Out:
#                   id  manufacturer_id  known_as      image_id     price_min  \
# count    1000.000000      1000.000000       0.0  1.000000e+03    710.000000
# mean   411718.815000      7956.248000       NaN  2.942035e+06   2568.673239
# std     97399.667595      4422.892837       NaN  5.273192e+05   7070.171637
# min     32891.000000        21.000000       NaN  7.628000e+04     16.000000
# 25%    353525.750000      5530.000000       NaN  2.968990e+06    369.000000
# 50%    442768.500000      8360.000000       NaN  3.127819e+06    750.000000
# 75%    491954.250000     10225.000000       NaN  3.223000e+06   1586.500000
# max    522362.000000     20749.000000       NaN  3.275590e+06  79643.000000
#
#           price_max  price_diff  price_count  price_suggested  review_rating  \
# count    132.000000        24.0   133.000000             24.0      50.000000
# mean    3089.916667         0.0     7.248120              0.0       0.880000
# ...

# %%
products_raw.hist()
plt.show()
